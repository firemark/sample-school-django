# %%
import school.wsgi
import pandas as pd
from school.models import City, School

# %%
School.objects.count()
# Out:
# 6857

# %%
City.objects.filter(name__startswith='B')
# Out:
# <QuerySet [<City: Będzin>, <City: Bobrowniki>, <City: Boguchwałowice>, <City: Brzękowice-Wał>, <City: Brudzowice>, <City: Bestwina>, <City: Bestwinka>, <City: Buczkowice>, <City: Bronów>, <City: Bujaków>, <City: Bystra>, <City: Brenna>, <City: Bażanowice>, <City: Bąków>, <City: Blachownia>, <City: Biała Wielka>, <City: Brzyszów>, <City: Borowno>, <City: Biskupice>, <City: Bojszów>, '...(remaining elements truncated)...']>

# %%
_.count()
# Out:
# 46

# %%
from django_pandas.io import read_frame

# %%
cities = read_frame(City.objects.all())
schools = read_frame(School.objects.all())

# %%
cities[:10]
# Out:
#    id          name  coutry_code  district_code  comm_code
# 0   1        Będzin           24              1          1
# 1   2       Czeladź           24              1          2
# 2   3     Wojkowice           24              1          3
# 3   4    Bobrowniki           24              1          4
# 4   5      Rogoźnik           24              1          4
# 5   6      Siemonia           24              1          4
# 6   7        Sączów           24              1          4
# 7   8  Dobieszowice           24              1          4
# 8   9    Mierzęcice           24              1          5
# 9  10     Przeczyce           24              1          5

# %%
b_cities = cities[cities.name.str.startswith('B')].sort_values(['name'])

# %%
len(b_cities)
# Out:
# 46

# %%
b_cities[:20]
# Out:
#       id            name  coutry_code  district_code  comm_code
# 378  379          Babice           24             11          6
# 211  212       Bargłówka           24              5          6
# 79    80      Bażanowice           24              3          7
# 27    28        Bestwina           24              2          2
# 28    29       Bestwinka           24              2          2
# 393  394            Bełk           24             12          1
# 224  225           Biała           24              6          1
# 145  146    Biała Wielka           24              4          9
# 555  556   Bielsko-Biała           24             61          1
# 522  523          Bierna           24             17          8
# 439  440          Bieruń           24             14          1
# 367  368      Bieńkowice           24             11          4
# 256  257          Bieżeń           24              6          9
# 170  171       Biskupice           24              4         12
# 105  106      Blachownia           24              4          1
# 315  316         Bliżyce           24              9          3
# 459  460       Bluszczów           24             15          6
# 3      4      Bobrowniki           24              1          4
# 10    11  Boguchwałowice           24              1          5
# 442  443        Bojszowy           24             14          4

# %%
schools[:10]
# Out:
#    id  school_code                                               name    city  \
# 0   1  Przedszkole                          Przedszkole Miejskie nr 1  Będzin
# 1   2  Przedszkole              Przedszkole Miejskie nr 10 w Będzinie  Będzin
# 2   3  Przedszkole              Przedszkole Miejskie nr 11 w Będzinie  Będzin
# 3   4  Przedszkole              Przedszkole Miejskie nr 12 w Będzinie  Będzin
# 4   5  Przedszkole  PRZEDSZKOLE MIEJSKIE NR 13 IM. JULIANA TUWIMA ...  Będzin
# 5   6  Przedszkole              Przedszkole Miejskie nr 14 w Będzinie  Będzin
# 6   7  Przedszkole              Przedszkole Miejskie nr 15 w Będzinie  Będzin
# 7   8  Przedszkole               Przedszkole Miejskie nr 2 w Będzinie  Będzin
# 8   9  Przedszkole               Przedszkole Miejskie nr 4 w Będzinie  Będzin
# 9  10  Przedszkole  Przedszkole Miejskie nr 5 im.Króla Maciusia Pi...  Będzin
#
#          street street_nr zip_code                     patron  \
# 0        Zawale         7   42-500
# 1      Kielecka        11   42-500
# 2      Podłosie        10   42-504
# 3       Radosna        8a   42-504
# 4    SKALSKIEGO         4   42-500               JULIAN TUWIM
# 5     Traugutta        1a   42-506
# 6   Barlickiego        75   42-506
# 7    Turniejowa         5   42-500  Kawalerów Orderu Uśmiechu
# 8  Rutkowskiego        3A   42-500               Jan Brzechwa
# 9    Zwycięstwa        21   42-500       Król Maciuś Pierwszy
#
#                                                site  telephone  boys  girls  \
# 0                www.przedszkole1bedzin.edupage.org  322674484    57     67
# 1               www.przedszkole10bedzin.edupage.org  322676087    50     75
# 2  www.przedszkolemiejskie11bedzin.przedszkolowo.pl  323637732    14     11
# 3                        www.pm12bedzin.edupage.org  322675759    56     29
# 4                            pm13bedzin.edupage.org  327352525    82    110
# 5                                   www.edupage.org  322675832    48     41
# 6                    www.przedszkole15bedzin.com.pl  327602632    57     66
# 7                             pm2bedzin.edupage.org  327783360    84     59
# 8                             pm4bedzin.edupage.org  232678089    74     91
# 9                                     www.p5.eys.pl  327612332    48     63
#
#    agencies  fulltime_teachers  nonfulltime_teachers
# 0         5                  8                     3
# 1         5                  9                     4
# 2         1                  2                     4
# 3         4                  6                     5
# 4         8                 15                     2
# 5         4                  7                     3
# 6         5                  9                     4
# 7         6                 14                     2
# 8         7                 12                     4
# 9         5                 11                     7

# %%
schools.groupby('city').size().sort_values(ascending=False)[:20]
# Out:
# city
# Katowice            546
# Częstochowa         360
# Bielsko-Biała       312
# Gliwice             304
# Sosnowiec           277
# Zabrze              271
# Rybnik              214
# Bytom               200
# Tychy               177
# Chorzów             165
# Jastrzębie-Zdrój    161
# Dąbrowa Górnicza    157
# Jaworzno            149
# Ruda Śląska         138
# Wodzisław Śląski    112
# Racibórz            111
# Żory                105
# Tarnowskie Góry     103
# Żywiec               95
# Cieszyn              94
# dtype: int64

# %%
schools.groupby('city')[
    ['boys', 'girls', 'fulltime_teachers']
].agg(['mean', 'sum']).sort_values(('boys', 'sum'), ascending=False)
# Out:
#                            boys             girls        fulltime_teachers  \
#                            mean    sum       mean    sum              mean
# city
# Katowice              43.412088  23703  45.697802  24951          7.840659
# Częstochowa           61.050000  21978  60.111111  21640         10.700000
# Bielsko-Biała         55.064103  17180  56.266026  17555          9.682692
# Gliwice               50.796053  15442  52.789474  16048          8.305921
# Sosnowiec             53.602888  14848  54.061372  14975          8.906137
# Zabrze                52.214022  14150  52.623616  14261          9.129151
# Rybnik                61.827103  13231  61.172897  13091         10.158879
# Bytom                 65.070000  13014  67.780000  13556         12.035000
# Ruda Śląska           76.862319  10607  73.108696  10089         13.514493
# Tychy                 58.468927  10349  59.971751  10615          9.983051
# Chorzów               61.496970  10147  61.527273  10152         10.066667
# Dąbrowa Górnicza      61.433121   9645  62.114650   9752         11.668790
# Jastrzębie-Zdrój      51.956522   8365  50.559006   8140          8.105590
# Jaworzno              51.617450   7691  51.859060   7727          9.255034
# Tarnowskie Góry       65.165049   6712  65.184466   6714          9.854369
# Racibórz              51.963964   5768  55.099099   6116          9.693694
# Żory                  52.285714   5490  53.428571   5610          9.485714
# Mysłowice             58.989011   5368  57.626374   5244         11.472527
# Żywiec                54.442105   5172  51.263158   4870          9.136842
# Wodzisław Śląski      45.866071   5137  46.982143   5262          7.580357
# Cieszyn               51.361702   4828  48.925532   4599          9.436170
# Zawiercie             55.547619   4666  57.630952   4841          9.892857
# Siemianowice Śląskie  61.213333   4591  63.066667   4730         10.786667
# Będzin                63.802817   4530  63.929577   4539         10.549296
# Piekary Śląskie       76.452830   4052  73.283019   3884         11.792453
# Mikołów               58.107692   3777  54.661538   3553         10.523077
# Świętochłowice        70.125000   3366  69.875000   3354         12.041667
# Pszczyna              66.520000   3326  64.300000   3215         13.420000
# Knurów                64.574468   3035  62.297872   2928         10.574468
# Czechowice-Dziedzice  63.234043   2972  58.042553   2728         11.531915
# ...                         ...    ...        ...    ...               ...
# Kuchary               15.000000     15  19.000000     19          2.000000
# Cyprzanów             15.000000     15  15.000000     15          0.000000
# Kuźnica Stara         15.000000     15  17.000000     17          5.000000
# Biskupice             15.000000     15  20.000000     20          3.000000
# Owsiszcze              5.000000     15   8.000000     24          1.333333
# Zawada Książęca        7.500000     15   8.000000     16          3.000000
# Glinica               14.000000     14  20.000000     20          0.000000
# Łany Wielkie          13.000000     13   4.000000      4          1.000000
# Gołuchowice           12.000000     12  13.000000     13         11.000000
# Złatna                11.000000     11  12.000000     12          0.000000
# Siedlec                5.000000     10   7.000000     14          1.000000
# Soblówka               3.333333     10   2.000000      6          0.333333
# Drochlin              10.000000     10  11.000000     11          0.000000
# Brzękowice-Wał        10.000000     10  11.000000     11          5.000000
# Łagiewniki Wielkie     8.000000      8  12.000000     12          2.000000
# Jarząbkowice           8.000000      8   7.000000      7          0.000000
# Grodzisko              8.000000      8   4.000000      4          3.000000
# Bierna                 8.000000      8  23.000000     23          0.000000
# Bolesław               7.000000      7  10.000000     10          0.000000
# Rachowice              6.000000      6   9.000000      9          2.000000
# Tomiszowice            2.500000      5   3.000000      6          0.500000
# Smolnica               4.000000      4   6.000000      6          1.000000
# Hutka                  4.000000      4   0.000000      0          0.000000
# Szałsza                4.000000      4   4.000000      4          1.000000
# Przyłubsko             3.000000      3   2.000000      2          1.000000
# Osiny                  3.000000      3   1.000000      1          0.000000
# Pawełki                0.000000      0   0.000000      0          0.000000
# Maków                  0.000000      0   0.000000      0          0.000000
# Lubockie               0.000000      0   0.000000      0          0.000000
# Hadra                  0.000000      0   0.000000      0          0.000000
#
#
#                        sum
# city
# Katowice              4281
# Częstochowa           3852
# Bielsko-Biała         3021
# Gliwice               2525
# Sosnowiec             2467
# Zabrze                2474
# Rybnik                2174
# Bytom                 2407
# Ruda Śląska           1865
# Tychy                 1767
# Chorzów               1661
# Dąbrowa Górnicza      1832
# Jastrzębie-Zdrój      1305
# Jaworzno              1379
# Tarnowskie Góry       1015
# Racibórz              1076
# Żory                   996
# Mysłowice             1044
# Żywiec                 868
# Wodzisław Śląski       849
# Cieszyn                887
# Zawiercie              831
# Siemianowice Śląskie   809
# Będzin                 749
# Piekary Śląskie        625
# Mikołów                684
# Świętochłowice         578
# Pszczyna               671
# Knurów                 497
# Czechowice-Dziedzice   542
# ...                    ...
# Kuchary                  2
# Cyprzanów                0
# Kuźnica Stara            5
# Biskupice                3
# Owsiszcze                4
# Zawada Książęca          6
# Glinica                  0
# Łany Wielkie             1
# Gołuchowice             11
# Złatna                   0
# Siedlec                  2
# Soblówka                 1
# Drochlin                 0
# Brzękowice-Wał           5
# Łagiewniki Wielkie       2
# Jarząbkowice             0
# Grodzisko                3
# Bierna                   0
# Bolesław                 0
# Rachowice                2
# Tomiszowice              1
# Smolnica                 1
# Hutka                    0
# Szałsza                  1
# Przyłubsko               1
# Osiny                    0
# Pawełki                  0
# Maków                    0
# Lubockie                 0
# Hadra                    0
#
# [562 rows x 6 columns]

# %%
schools['students'] = schools.apply(lambda r: r['boys'] + r['girls'], axis=1)

# %%
import matplotlib
# %matplotlib inline
(
    schools[schools.school_code == 'Gimnazjum']
    .groupby('city')
    .sum()[['students', 'girls', 'boys']]
    .sort_values('students', ascending=False)[:20]
    .plot(kind='bar', figsize=(15, 5))
)

# %%
(
    schools.groupby('school_code')
    .sum()[['students', 'girls', 'boys']]
    .sort_values('students', ascending=False)[:20]
    .plot(kind='bar', figsize=(15, 5))
)
